# %% [markdown]
# # A Multi-Method Analysis of the Russian Housing Market
# ### 3804ICT Assignment Part I | Data Investigation Notebook | Trimester 2, 2019
#
# Joshua Russell (s5057545) | joshua.russell2@griffithuni.edu.au
#
#
# Joshua Mitchell (s5055278) | joshua.mitchell4@griffithuni.edu.au
#
#
# Hayden Flatley (s5088623) | hayden.flatley@griffithuni.edu.au

# %% [markdown]
# //(Intro)
#
# The sections of the data investigation are as follows:
#
# **1. Data Exploration**
#
#     1.1. Number of Data Samples and Attributes
#
# **2. Data Visualisation**
#
# - Heading
#     - Sub-heading
#
# **3. Data Pre-Processing**
#
# - Heading
#     - Sub-heading

# %% [markdown]
# ![title](SS.png)

# %%
# Imports
import math
import folium
import random
import statistics
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb

from sklearn import model_selection, preprocessing
from IPython.display import display
from geopy.geocoders import Nominatim

# %%
# Load the Russian Housing Market datasets into pandas DataFrames
df_test = pd.read_csv("Data/test.csv")
df_train = pd.read_csv("Data/train.csv")

# %% [markdown]
# ## 1. Data Exploration

# %% [markdown]
# ### 1.1. Number of Data Samples and Attributes

# %% [markdown]
# The primary property dataset was provided online in two seperate files for training and testing. Below, we display the number of data samples and attributes in each of the datasets:

# %%
# Testing set
print("Testing set\n- No. data samples: {}\n- No. of attributes: {}".format(df_test.shape[0], df_test.shape[1]))
# Out:
# Testing set
# - No. data samples: 7662
# - No. of attributes: 291

# %%
# Training set
print("Training set\n- No. data samples: {}\n- No. of attributes: {}".format(df_train.shape[0], df_train.shape[1]))
# Out:
# Training set
# - No. data samples: 30471
# - No. of attributes: 292

# %% [markdown]
# The testing set has one less attribute than that of the training set. The following code checks the name of this attribute:

# %%
list(set(df_train.columns).difference(set(df_test.columns)))[0]
# Out:
# 'price_doc'

# %% [markdown]
# The data dictionary of the Russian Housing Market dataset describes this attribute as the sale price of the property, and moreover as the target variable for house price prediction. These two datasets will be useful for the methods of regression and forecasting. However, for other data mining methods we plan to investigate, such as frequent pattern mining, there is no need to split the data into training and testing sets. As a result, we will concatenate the datasets together for pre-processing.

# %%
# Add a 'price_doc' column to the test DataFrame filled with `None` values
# df_test_price_doc = df_test.assign(price_doc=pd.Series([None for i in range(df_test.shape[0])]).values)

# %%
# Concatenate test and train DataFrames
df = pd.concat([df_train, df_test], sort=False, ignore_index=True)

# %%
# Concatenate datasets (both training and testing data samples)
print("Complete dataset\n- No. data samples: {}\n- No. of attributes: {}".format(df.shape[0], df.shape[1]))
# Out:
# Complete dataset
# - No. data samples: 38133
# - No. of attributes: 292

# %% [markdown]
# ### 1.2. Types of Attributes

# %% [markdown]
# Here we investigate the types of attributes within the dataset. For an initial look at these attributes we display each attribute with its corresponding datatype and an example value from the dataset

# %%
# Attributes with corresponding Datatypes and Examples from the Russian Housing Market dataset
print("{:<40} {:<15} {}".format("Attribute", "Datatype", "Example Value"))
print("{:<40} {:<15} {}".format("---------", "--------", "-------------"))

example_values = []
for col in list(df.columns):
    values = [x for x in list(df[col].values) if str(x) != "nan"]
    example_values.append(values[0])
    
for col in np.c_[list(df.columns), list(df.dtypes), list(example_values)]:
    print("{:<40} {:<15} {}".format(col[0], str(col[1]), col[2]))
# Out:
# Attribute                                Datatype        Example Value
# ---------                                --------        -------------
# id                                       int64           1
# timestamp                                object          2011-08-20
# full_sq                                  float64         43.0
# life_sq                                  float64         27.0
# floor                                    float64         4.0
# max_floor                                float64         17.0
# material                                 float64         1.0
# build_year                               float64         1907.0
# num_room                                 float64         2.0
# kitch_sq                                 float64         11.0
# state                                    float64         3.0
# product_type                             object          Investment
# sub_area                                 object          Bibirevo
# area_m                                   float64         6407578.1
# raion_popul                              int64           155572
# green_zone_part                          float64         0.189727117
# indust_part                              float64         6.99893e-05
# children_preschool                       int64           9576
# preschool_quota                          float64         5001.0
# preschool_education_centers_raion        int64           5
# children_school                          int64           10309
# school_quota                             float64         11065.0
# school_education_centers_raion           int64           5
# school_education_centers_top_20_raion    int64           0
# hospital_beds_raion                      float64         240.0
# healthcare_centers_raion                 int64           1
# university_top_20_raion                  int64           0
# sport_objects_raion                      int64           7
# additional_education_raion               int64           3
# culture_objects_top_25                   object          no
# culture_objects_top_25_raion             int64           0
# shopping_centers_raion                   int64           16
# office_raion                             int64           1
# thermal_power_plant_raion                object          no
# incineration_raion                       object          no
# oil_chemistry_raion                      object          no
# radiation_raion                          object          no
# railroad_terminal_raion                  object          no
# big_market_raion                         object          no
# nuclear_reactor_raion                    object          no
# detention_facility_raion                 object          no
# full_all                                 int64           86206
# male_f                                   int64           40477
# female_f                                 int64           45729
# young_all                                int64           21154
# young_male                               int64           11007
# young_female                             int64           10147
# work_all                                 int64           98207
# work_male                                int64           52277
# work_female                              int64           45930
# ekder_all                                int64           36211
# ekder_male                               int64           10580
# ekder_female                             int64           25631
# 0_6_all                                  int64           9576
# 0_6_male                                 int64           4899
# 0_6_female                               int64           4677
# 7_14_all                                 int64           10309
# 7_14_male                                int64           5463
# 7_14_female                              int64           4846
# 0_17_all                                 int64           23603
# 0_17_male                                int64           12286
# 0_17_female                              int64           11317
# 16_29_all                                int64           17508
# 16_29_male                               int64           9425
# 16_29_female                             int64           8083
# 0_13_all                                 int64           18654
# 0_13_male                                int64           9709
# 0_13_female                              int64           8945
# raion_build_count_with_material_info     float64         211.0
# build_count_block                        float64         25.0
# build_count_wood                         float64         0.0
# build_count_frame                        float64         0.0
# build_count_brick                        float64         0.0
# build_count_monolith                     float64         2.0
# build_count_panel                        float64         184.0
# build_count_foam                         float64         0.0
# build_count_slag                         float64         0.0
# build_count_mix                          float64         0.0
# raion_build_count_with_builddate_info    float64         211.0
# build_count_before_1920                  float64         0.0
# build_count_1921-1945                    float64         0.0
# build_count_1946-1970                    float64         0.0
# build_count_1971-1995                    float64         206.0
# build_count_after_1995                   float64         5.0
# ID_metro                                 int64           1
# metro_min_avto                           float64         2.590241095
# metro_km_avto                            float64         1.131259906
# metro_min_walk                           float64         13.57511887
# metro_km_walk                            float64         1.131259906
# kindergarten_km                          float64         0.14569955199999998
# school_km                                float64         0.17797535
# park_km                                  float64         2.158587074
# green_zone_km                            float64         0.600973099
# industrial_km                            float64         1.080934313
# water_treatment_km                       float64         23.68346
# cemetery_km                              float64         1.804127
# incineration_km                          float64         3.6333339999999996
# railroad_station_walk_km                 float64         5.419893032
# railroad_station_walk_min                float64         65.03871639
# ID_railroad_station_walk                 float64         1.0
# railroad_station_avto_km                 float64         5.419893032
# railroad_station_avto_min                float64         6.905892968
# ID_railroad_station_avto                 int64           1
# public_transport_station_km              float64         0.274985143
# public_transport_station_min_walk        float64         3.2998217139999997
# water_km                                 float64         0.992631058
# water_1line                              object          no
# mkad_km                                  float64         1.42239141
# ttk_km                                   float64         10.9185867
# sadovoe_km                               float64         13.10061764
# bulvar_ring_km                           float64         13.67565705
# kremlin_km                               float64         15.15621058
# big_road1_km                             float64         1.422391404
# ID_big_road1                             int64           1
# big_road1_1line                          object          no
# big_road2_km                             float64         3.830951404
# ID_big_road2                             int64           5
# railroad_km                              float64         1.305159492
# railroad_1line                           object          no
# zd_vokzaly_avto_km                       float64         14.23196091
# ID_railroad_terminal                     int64           101
# bus_terminal_avto_km                     float64         24.2924061
# ID_bus_terminal                          int64           1
# oil_chemistry_km                         float64         18.152338
# nuclear_reactor_km                       float64         5.718518835
# radiation_km                             float64         1.210027392
# power_transmission_line_km               float64         1.0625130459999999
# thermal_power_plant_km                   float64         5.814134663
# ts_km                                    float64         4.308127002
# big_market_km                            float64         10.81417151
# market_shop_km                           float64         1.6762583130000002
# fitness_km                               float64         0.485841388
# swim_pool_km                             float64         3.0650470989999996
# ice_rink_km                              float64         1.1075942090000002
# stadium_km                               float64         8.148590774
# basketball_km                            float64         3.5165129110000004
# hospice_morgue_km                        float64         2.392353035
# detention_facility_km                    float64         4.2480358869999995
# public_healthcare_km                     float64         0.974742843
# university_km                            float64         6.715025787
# workplaces_km                            float64         0.8843500209999999
# shopping_centers_km                      float64         0.648487637
# office_km                                float64         0.637188832
# additional_education_km                  float64         0.947961657
# preschool_km                             float64         0.17797535
# big_church_km                            float64         0.625783434
# church_synagogue_km                      float64         0.628186549
# mosque_km                                float64         3.932040333
# theater_km                               float64         14.05304655
# museum_km                                float64         7.389497904
# exhibition_km                            float64         7.023704919
# catering_km                              float64         0.516838085
# ecology                                  object          good
# green_part_500                           float64         0.0
# prom_part_500                            float64         0.0
# office_count_500                         int64           0
# office_sqm_500                           int64           0
# trc_count_500                            int64           0
# trc_sqm_500                              int64           0
# cafe_count_500                           int64           0
# cafe_sum_500_min_price_avg               float64         860.0
# cafe_sum_500_max_price_avg               float64         1500.0
# cafe_avg_price_500                       float64         1180.0
# cafe_count_500_na_price                  int64           0
# cafe_count_500_price_500                 int64           0
# cafe_count_500_price_1000                int64           0
# cafe_count_500_price_1500                int64           0
# cafe_count_500_price_2500                int64           0
# cafe_count_500_price_4000                int64           0
# cafe_count_500_price_high                int64           0
# big_church_count_500                     int64           0
# church_count_500                         int64           0
# mosque_count_500                         int64           0
# leisure_count_500                        int64           0
# sport_count_500                          int64           1
# market_count_500                         int64           0
# green_part_1000                          float64         7.36
# prom_part_1000                           float64         0.0
# office_count_1000                        int64           1
# office_sqm_1000                          int64           30500
# trc_count_1000                           int64           3
# trc_sqm_1000                             int64           55600
# cafe_count_1000                          int64           19
# cafe_sum_1000_min_price_avg              float64         527.78
# cafe_sum_1000_max_price_avg              float64         888.89
# cafe_avg_price_1000                      float64         708.33
# cafe_count_1000_na_price                 int64           1
# cafe_count_1000_price_500                int64           10
# cafe_count_1000_price_1000               int64           4
# cafe_count_1000_price_1500               int64           3
# cafe_count_1000_price_2500               int64           1
# cafe_count_1000_price_4000               int64           0
# cafe_count_1000_price_high               int64           0
# big_church_count_1000                    int64           1
# church_count_1000                        int64           2
# mosque_count_1000                        int64           0
# leisure_count_1000                       int64           0
# sport_count_1000                         int64           6
# market_count_1000                        int64           1
# green_part_1500                          float64         14.27
# prom_part_1500                           float64         6.92
# office_count_1500                        int64           3
# office_sqm_1500                          int64           39554
# trc_count_1500                           int64           9
# trc_sqm_1500                             int64           171420
# cafe_count_1500                          int64           34
# cafe_sum_1500_min_price_avg              float64         566.67
# cafe_sum_1500_max_price_avg              float64         969.7
# cafe_avg_price_1500                      float64         768.18
# cafe_count_1500_na_price                 int64           1
# cafe_count_1500_price_500                int64           14
# cafe_count_1500_price_1000               int64           11
# cafe_count_1500_price_1500               int64           6
# cafe_count_1500_price_2500               int64           2
# cafe_count_1500_price_4000               int64           0
# cafe_count_1500_price_high               int64           0
# big_church_count_1500                    int64           1
# church_count_1500                        int64           2
# mosque_count_1500                        int64           0
# leisure_count_1500                       int64           0
# sport_count_1500                         int64           7
# market_count_1500                        int64           1
# green_part_2000                          float64         11.77
# prom_part_2000                           float64         15.97
# office_count_2000                        int64           9
# office_sqm_2000                          int64           188854
# trc_count_2000                           int64           19
# trc_sqm_2000                             int64           1244891
# cafe_count_2000                          int64           36
# cafe_sum_2000_min_price_avg              float64         614.29
# cafe_sum_2000_max_price_avg              float64         1042.86
# cafe_avg_price_2000                      float64         828.57
# cafe_count_2000_na_price                 int64           1
# cafe_count_2000_price_500                int64           15
# cafe_count_2000_price_1000               int64           11
# cafe_count_2000_price_1500               int64           6
# cafe_count_2000_price_2500               int64           2
# cafe_count_2000_price_4000               int64           1
# cafe_count_2000_price_high               int64           0
# big_church_count_2000                    int64           1
# church_count_2000                        int64           2
# mosque_count_2000                        int64           0
# leisure_count_2000                       int64           0
# sport_count_2000                         int64           10
# market_count_2000                        int64           1
# green_part_3000                          float64         11.98
# prom_part_3000                           float64         13.55
# office_count_3000                        int64           12
# office_sqm_3000                          int64           251554
# trc_count_3000                           int64           23
# trc_sqm_3000                             int64           1419204
# cafe_count_3000                          int64           68
# cafe_sum_3000_min_price_avg              float64         639.68
# cafe_sum_3000_max_price_avg              float64         1079.37
# cafe_avg_price_3000                      float64         859.52
# cafe_count_3000_na_price                 int64           5
# cafe_count_3000_price_500                int64           21
# cafe_count_3000_price_1000               int64           22
# cafe_count_3000_price_1500               int64           16
# cafe_count_3000_price_2500               int64           3
# cafe_count_3000_price_4000               int64           1
# cafe_count_3000_price_high               int64           0
# big_church_count_3000                    int64           2
# church_count_3000                        int64           4
# mosque_count_3000                        int64           0
# leisure_count_3000                       int64           0
# sport_count_3000                         int64           21
# market_count_3000                        int64           1
# green_part_5000                          float64         13.09
# prom_part_5000                           float64         13.31
# office_count_5000                        int64           29
# office_sqm_5000                          int64           807385
# trc_count_5000                           int64           52
# trc_sqm_5000                             int64           4036616
# cafe_count_5000                          int64           152
# cafe_sum_5000_min_price_avg              float64         708.57
# cafe_sum_5000_max_price_avg              float64         1185.71
# cafe_avg_price_5000                      float64         947.14
# cafe_count_5000_na_price                 int64           12
# cafe_count_5000_price_500                int64           39
# cafe_count_5000_price_1000               int64           48
# cafe_count_5000_price_1500               int64           40
# cafe_count_5000_price_2500               int64           9
# cafe_count_5000_price_4000               int64           4
# cafe_count_5000_price_high               int64           0
# big_church_count_5000                    int64           13
# church_count_5000                        int64           22
# mosque_count_5000                        int64           1
# leisure_count_5000                       int64           0
# sport_count_5000                         int64           52
# market_count_5000                        int64           4
# price_doc                                float64         5850000.0

# %% [markdown]
# There are four distinct types of attributes, those being *nominal attributes*, *ordinal attributes*, *interval-scaled attributes* and *ratio-scaled attributes*. Furthermore, there are also discrete and continuous classifications for distinguishing types of attributes. Since there are a total of 292 attributes in the primary dataset we will not describe the specific attribute type for each attribute. Instead, we will provide examples of attributes from the dataset that fulfill the criteria of the different attribute types.
#
# **Nominal attributes**
#
# Nominal attributes are those which are qualitative and do not have any inherent order or ranking. An example of this type of attribute within the dataset is the `sub_area` attribute. This attribute represents the name of the district that the data sample (property) belongs to. It takes on values such as "Juzhnoe Butovo" and "Perovo".
#
# **Ordinal attributes**
#
# Ordinal attributes are again qualitative. However, the values that these attributes take on have a meaningful order. In the primary housing market dataset there are no attributes that are ordinal.
#
# **Interval-scaled attributes**
#
# Interval-scaled attributes are ordered, and are those which, as the name implies, are measured on a particular equal-sized interval scale. The distinguishing factor between interval-scaled attributes and ratio-scaled attributes is that interval-scaled attributes do not have a true zero point (i.e. they can be positive, zero, or negative). After observing the name and meaning of each of the attributes in the primary dataset, we did not find any attributes that appeared interval-scaled. We further check this observation below:

# %%
# Check for negative values in DataFrame
for col_name in list(df.columns):
    col = df[col_name]
    
    if col.dtype == "float64" or col.dtype == "int64":
        neg_values = []
        
        for val in col:
            if not math.isnan(val) and val < 0:
                neg_values.append(val)
                
        if neg_values:
            print("Column: {}".format(col_name))
            print("Negative values: {}".format(len(neg_values)))

# %% [markdown]
# **Ratio-scaled attributes**
#
# Ratio-scaled attributes, like those which are interval-scaled, are ordered measurements which have a particular scale. However, what differentiates ratio-scaled attributes is that they have a true zero point (i.e. they can be positive or zero). An example of a ratio-scaled attribute within the housing market dataset is `full_sq`. This attribute represents the total area of the property in square meters. Since area has an inherent zero-point, as you cannot have a house with negative area, this is a clear example of a ratio-scaled attribute.
#
# **Discrete attributes**
#
# Discrete attributes are attributes which take on a finite or countably infinite set of possible values. The attribute `product_type` is an example of a discrete attribute within the primary dataset. This attribute states whether the property was bought as an investment property, or for owner-occupancy. Since there are two possible values this attribute can take on (i.e. "OwnerOccupier" or "Investment"), it has a finite set of values and is therefore a discrete attribute.
#
# **Continuous attributes**
#
# Continuous attributes, in contrast to discrete attributes, take on real valued numbers over a continuous range. An example of this type of attribute in the Russian housing market dataset is `metro_min_walk`, which provides the time it would take to walk to the metro on foot from the property (in minutes). This attribute has floating-point values over a continuous range and can therefore be classified as a continuous attribute.

# %% [markdown]
# ### 1.3. Feature Selection

# %% [markdown]
# The primary Russian housing market dataset contains a significant number of attributes, 292 in total. Consequently, for this investigation we will perform feature selection to select a few attributes which seem interesting and/or significant for predicting property sale price to study in data exploration and visualisation. Firstly, we will perform manual feature selection by examining the features and using domain knowledge to determine which attributes should not be investigated. We will then use metrics and data analysis techniques to determine which attributes seem most promising to examine.

# %% [markdown]
# #### Manual Selection
#
# The following attributes were selected for data exploration and visualisation based upon our domain knowledge of what attributes would be significant in predicting house price and what attributes would be interesting to study.
#
# `price_doc` - this attribute represents the sale price of the property. This attribute will be interesting to explore as it allows us to find trends in the price and determine what other attributes are correlated to house price. Furthermore, the sale price will be the target variable for our regression and forecasting methods.
#
# `full_sq` - this attribute represents the total area of the property in square meters (including loggias, balconies and other non-residential living areas). We believe that the total area of the property would be a strong indicator for gauging the price of the property. As larger homes are generally more expensive than smaller ones.
#
# `sub_area` - this attribute represents the name of the district that the property is within. Characteristics of the district, such as its reputation, its population, or whether it has a large central business district will all affect the price of the property and other property/neighbourhood attribute values. Because of this, we thought that it would be interesting to explore.
#
# `num_room` - this attribute represents the number of living rooms
#
# `build_year` - this attribute represents the year that the property was built. Since newer appartments and homes are generally more expensive, we assume that this attribute will be useful for predicting house price. Furthermore, it may also allude to interesting relationships between house age and the district, or house age and the demographic information of the neighbourhood.
#
# `state` - this attribute represents the condition that the property is in at time of purchase.

# %% [markdown]
# #### Metric-Based Selection - Correlation Analysis

# %%
high_corr_list = df.corr()["price_doc"].abs().sort_values()[-30:].keys()

items_to_remove = ["trc_sqm_3000", "cafe_count_5000_na_price", "trc_count_3000", "sport_count_3000"]
high_corr_list = list(set(high_corr_list).difference(set(items_to_remove)))

corr = df[high_corr_list].corr()
# Out:
#                             sport_count_2000  kremlin_km  sadovoe_km  \
# sport_count_2000                    1.000000   -0.720607   -0.696815
# kremlin_km                         -0.720607    1.000000    0.997456
# sadovoe_km                         -0.696815    0.997456    1.000000
# sport_count_1500                    0.940268   -0.674142   -0.651306
# num_room                            0.098414   -0.076670   -0.077857
# trc_count_5000                      0.841519   -0.796151   -0.777997
# cafe_count_5000                     0.799873   -0.585392   -0.545589
# sport_objects_raion                 0.795029   -0.595501   -0.570696
# cafe_count_5000_price_1000          0.817159   -0.618013   -0.579844
# stadium_km                         -0.585212    0.905825    0.914587
# sport_count_5000                    0.889764   -0.824257   -0.804396
# trc_sqm_5000                        0.774329   -0.740402   -0.729350
# office_sqm_5000                     0.779261   -0.658706   -0.628464
# cafe_count_5000_price_500           0.803780   -0.591427   -0.552451
# cafe_count_5000_price_1500          0.795251   -0.579811   -0.539480
# ttk_km                             -0.633641    0.984665    0.992551
# office_sqm_3000                     0.774217   -0.594508   -0.557672
# bulvar_ring_km                     -0.716120    0.998819    0.998439
# price_doc                           0.278056   -0.279249   -0.283622
# cafe_count_5000_price_2500          0.773652   -0.547676   -0.506615
# detention_facility_km              -0.628723    0.825023    0.832519
# zd_vokzaly_avto_km                 -0.716945    0.965774    0.969778
# nuclear_reactor_km                 -0.505800    0.807279    0.812037
# office_km                          -0.521363    0.687744    0.691600
# basketball_km                      -0.526792    0.893282    0.902742
# full_sq                             0.013021    0.021471    0.024445
#
#                             sport_count_1500  num_room  trc_count_5000  \
# sport_count_2000                    0.940268  0.098414        0.841519
# kremlin_km                         -0.674142 -0.076670       -0.796151
# sadovoe_km                         -0.651306 -0.077857       -0.777997
# sport_count_1500                    1.000000  0.095773        0.792194
# num_room                            0.095773  1.000000        0.104994
# trc_count_5000                      0.792194  0.104994        1.000000
# cafe_count_5000                     0.751969  0.071485        0.803257
# sport_objects_raion                 0.787871  0.095101        0.698191
# cafe_count_5000_price_1000          0.766476  0.075283        0.831328
# stadium_km                         -0.553518 -0.065388       -0.626397
# sport_count_5000                    0.829399  0.096669        0.922323
# trc_sqm_5000                        0.735655  0.093719        0.893414
# office_sqm_5000                     0.728073  0.079368        0.827533
# cafe_count_5000_price_500           0.754644  0.071624        0.810405
# cafe_count_5000_price_1500          0.748001  0.072106        0.804455
# ttk_km                             -0.591247 -0.072949       -0.723506
# office_sqm_3000                     0.725878  0.065883        0.784685
# bulvar_ring_km                     -0.669494 -0.077596       -0.788376
# price_doc                           0.258376  0.476337        0.289371
# cafe_count_5000_price_2500          0.728695  0.067316        0.760841
# detention_facility_km              -0.598209 -0.071224       -0.649248
# zd_vokzaly_avto_km                 -0.674781 -0.081962       -0.778710
# nuclear_reactor_km                 -0.481103 -0.074657       -0.674071
# office_km                          -0.495370 -0.080896       -0.577468
# basketball_km                      -0.504783 -0.065328       -0.609475
# full_sq                             0.008506  0.702255        0.008077
#
#                             cafe_count_5000  sport_objects_raion  \
# sport_count_2000                   0.799873             0.795029
# kremlin_km                        -0.585392            -0.595501
# sadovoe_km                        -0.545589            -0.570696
# sport_count_1500                   0.751969             0.787871
# num_room                           0.071485             0.095101
# trc_count_5000                     0.803257             0.698191
# cafe_count_5000                    1.000000             0.686553
# sport_objects_raion                0.686553             1.000000
# cafe_count_5000_price_1000         0.997268             0.691548
# stadium_km                        -0.346020            -0.494739
# sport_count_5000                   0.857004             0.735895
# trc_sqm_5000                       0.696941             0.625508
# office_sqm_5000                    0.951495             0.664428
# cafe_count_5000_price_500          0.997907             0.681086
# cafe_count_5000_price_1500         0.998269             0.682817
# ttk_km                            -0.455970            -0.517144
# office_sqm_3000                    0.954734             0.660106
# bulvar_ring_km                    -0.570606            -0.588099
# price_doc                          0.231546             0.252794
# cafe_count_5000_price_2500         0.995728             0.679027
# detention_facility_km             -0.373209            -0.540718
# zd_vokzaly_avto_km                -0.521081            -0.576991
# nuclear_reactor_km                -0.307847            -0.418573
# office_km                         -0.320904            -0.458378
# basketball_km                     -0.306004            -0.441828
# full_sq                            0.039740             0.034837
#
#                             cafe_count_5000_price_1000  stadium_km  ...  \
# sport_count_2000                              0.817159   -0.585212  ...
# kremlin_km                                   -0.618013    0.905825  ...
# sadovoe_km                                   -0.579844    0.914587  ...
# sport_count_1500                              0.766476   -0.553518  ...
# num_room                                      0.075283   -0.065388  ...
# trc_count_5000                                0.831328   -0.626397  ...
# cafe_count_5000                               0.997268   -0.346020  ...
# sport_objects_raion                           0.691548   -0.494739  ...
# cafe_count_5000_price_1000                    1.000000   -0.380173  ...
# stadium_km                                   -0.380173    1.000000  ...
# sport_count_5000                              0.881153   -0.637947  ...
# trc_sqm_5000                                  0.718093   -0.620409  ...
# office_sqm_5000                               0.955924   -0.412185  ...
# cafe_count_5000_price_500                     0.996745   -0.351556  ...
# cafe_count_5000_price_1500                    0.995785   -0.338189  ...
# ttk_km                                       -0.492684    0.920221  ...
# office_sqm_3000                               0.952236   -0.357277  ...
# bulvar_ring_km                               -0.604123    0.910646  ...
# price_doc                                     0.240464   -0.236924  ...
# cafe_count_5000_price_2500                    0.987769   -0.308833  ...
# detention_facility_km                        -0.402404    0.828687  ...
# zd_vokzaly_avto_km                           -0.555589    0.905286  ...
# nuclear_reactor_km                           -0.339659    0.804087  ...
# office_km                                    -0.347450    0.706721  ...
# basketball_km                                -0.337900    0.909158  ...
# full_sq                                       0.037127    0.034749  ...
#
#                             office_sqm_3000  bulvar_ring_km  price_doc  \
# sport_count_2000                   0.774217       -0.716120   0.278056
# kremlin_km                        -0.594508        0.998819  -0.279249
# sadovoe_km                        -0.557672        0.998439  -0.283622
# sport_count_1500                   0.725878       -0.669494   0.258376
# num_room                           0.065883       -0.077596   0.476337
# trc_count_5000                     0.784685       -0.788376   0.289371
# cafe_count_5000                    0.954734       -0.570606   0.231546
# sport_objects_raion                0.660106       -0.588099   0.252794
# cafe_count_5000_price_1000         0.952236       -0.604123   0.240464
# stadium_km                        -0.357277        0.910646  -0.236924
# sport_count_5000                   0.843514       -0.820334   0.294864
# trc_sqm_5000                       0.694908       -0.735701   0.268072
# office_sqm_5000                    0.954223       -0.645301   0.269977
# cafe_count_5000_price_500          0.950896       -0.577624   0.226952
# cafe_count_5000_price_1500         0.952512       -0.564211   0.232612
# ttk_km                            -0.477570        0.987045  -0.272620
# office_sqm_3000                    1.000000       -0.578744   0.226780
# bulvar_ring_km                    -0.578744        1.000000  -0.279158
# price_doc                          0.226780       -0.279158   1.000000
# cafe_count_5000_price_2500         0.950500       -0.531958   0.225566
# detention_facility_km             -0.362549        0.837547  -0.223061
# zd_vokzaly_avto_km                -0.531173        0.970838  -0.284069
# nuclear_reactor_km                -0.328337        0.802443  -0.257946
# office_km                         -0.341220        0.691614  -0.223429
# basketball_km                     -0.309176        0.899117  -0.223462
# full_sq                            0.033717        0.023591   0.341840
#
#                             cafe_count_5000_price_2500  detention_facility_km  \
# sport_count_2000                              0.773652              -0.628723
# kremlin_km                                   -0.547676               0.825023
# sadovoe_km                                   -0.506615               0.832519
# sport_count_1500                              0.728695              -0.598209
# num_room                                      0.067316              -0.071224
# trc_count_5000                                0.760841              -0.649248
# cafe_count_5000                               0.995728              -0.373209
# sport_objects_raion                           0.679027              -0.540718
# cafe_count_5000_price_1000                    0.987769              -0.402404
# stadium_km                                   -0.308833               0.828687
# sport_count_5000                              0.825365              -0.657669
# trc_sqm_5000                                  0.660520              -0.657300
# office_sqm_5000                               0.941129              -0.408750
# cafe_count_5000_price_500                     0.990609              -0.381798
# cafe_count_5000_price_1500                    0.993191              -0.360691
# ttk_km                                       -0.415978               0.837114
# office_sqm_3000                               0.950500              -0.362549
# bulvar_ring_km                               -0.531958               0.837547
# price_doc                                     0.225566              -0.223061
# cafe_count_5000_price_2500                    1.000000              -0.335810
# detention_facility_km                        -0.335810               1.000000
# zd_vokzaly_avto_km                           -0.480166               0.864181
# nuclear_reactor_km                           -0.265444               0.784839
# office_km                                    -0.288351               0.676505
# basketball_km                                -0.268070               0.849630
# full_sq                                       0.044089               0.037533
#
#                             zd_vokzaly_avto_km  nuclear_reactor_km  office_km  \
# sport_count_2000                     -0.716945           -0.505800  -0.521363
# kremlin_km                            0.965774            0.807279   0.687744
# sadovoe_km                            0.969778            0.812037   0.691600
# sport_count_1500                     -0.674781           -0.481103  -0.495370
# num_room                             -0.081962           -0.074657  -0.080896
# trc_count_5000                       -0.778710           -0.674071  -0.577468
# cafe_count_5000                      -0.521081           -0.307847  -0.320904
# sport_objects_raion                  -0.576991           -0.418573  -0.458378
# cafe_count_5000_price_1000           -0.555589           -0.339659  -0.347450
# stadium_km                            0.905286            0.804087   0.706721
# sport_count_5000                     -0.802969           -0.578102  -0.548313
# trc_sqm_5000                         -0.744610           -0.658578  -0.545622
# office_sqm_5000                      -0.601661           -0.398515  -0.377263
# cafe_count_5000_price_500            -0.531248           -0.311856  -0.328175
# cafe_count_5000_price_1500           -0.512328           -0.304782  -0.315804
# ttk_km                                0.959897            0.824725   0.683589
# office_sqm_3000                      -0.531173           -0.328337  -0.341220
# bulvar_ring_km                        0.970838            0.802443   0.691614
# price_doc                            -0.284069           -0.257946  -0.223429
# cafe_count_5000_price_2500           -0.480166           -0.265444  -0.288351
# detention_facility_km                 0.864181            0.784839   0.676505
# zd_vokzaly_avto_km                    1.000000            0.828506   0.719492
# nuclear_reactor_km                    0.828506            1.000000   0.736333
# office_km                             0.719492            0.736333   1.000000
# basketball_km                         0.904809            0.849030   0.747442
# full_sq                               0.031414            0.018867   0.027733
#
#                             basketball_km   full_sq
# sport_count_2000                -0.526792  0.013021
# kremlin_km                       0.893282  0.021471
# sadovoe_km                       0.902742  0.024445
# sport_count_1500                -0.504783  0.008506
# num_room                        -0.065328  0.702255
# trc_count_5000                  -0.609475  0.008077
# cafe_count_5000                 -0.306004  0.039740
# sport_objects_raion             -0.441828  0.034837
# cafe_count_5000_price_1000      -0.337900  0.037127
# stadium_km                       0.909158  0.034749
# sport_count_5000                -0.575209  0.008517
# trc_sqm_5000                    -0.578596  0.000279
# office_sqm_5000                 -0.361900  0.032578
# cafe_count_5000_price_500       -0.314013  0.035770
# cafe_count_5000_price_1500      -0.300131  0.041949
# ttk_km                           0.916646  0.030657
# office_sqm_3000                 -0.309176  0.033717
# bulvar_ring_km                   0.899117  0.023591
# price_doc                       -0.223462  0.341840
# cafe_count_5000_price_2500      -0.268070  0.044089
# detention_facility_km            0.849630  0.037533
# zd_vokzaly_avto_km               0.904809  0.031414
# nuclear_reactor_km               0.849030  0.018867
# office_km                        0.747442  0.027733
# basketball_km                    1.000000  0.038515
# full_sq                          0.038515  1.000000
#
# [26 rows x 26 columns]

# %%
for f in df_train.columns:
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(240, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .6})
plt.show()

# %% [markdown]
# #### Metric-Based Selection - XGB Classifier*

# %% [markdown]
# Another algorithm which determines stronger relationships between attributes and a target result such as the house price is Extreme Gradient Boosting. This algorithm constructs a gradient boosted tree, which is essentially an optimised decision tree, to assign attributes scores on how influential they are in classifying the output.
#
# The algorithm requires categorical data to be encoded so the code below first converts all data of type object to an encoded label.
#
# Parameters that the tree model for the XBG library require include the max depth of the tree, learning rate(eta) and error function.

# %%
for f in df_train.columns:
    if df_train[f].dtype=='object':
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(df_train[f].values)) 
        df_train[f] = lbl.transform(list(df_train[f].values))

y_train = df_train.price_doc.values
x_train = df_train.drop(["id", "timestamp", "price_doc"], axis=1)


param = {'max_depth': 10, 'eta': 1, 'objective': 'reg:squarederror'}


dtrain = xgb.DMatrix(x_train, y_train, feature_names=x_train.columns.values)
model = xgb.train(dict(param, silent=0), dtrain, num_boost_round=10)

import itertools 

importance = model.get_score()
importance = dict(sorted(importance.items(), key=lambda importance: importance[1], reverse=True))
importance = dict(itertools.islice(importance.items(), 20))
importance
# Out:
# {'full_sq': 482,
#  'life_sq': 185,
#  'floor': 174,
#  'max_floor': 104,
#  'build_year': 89,
#  'kitch_sq': 56,
#  'state': 47,
#  'num_room': 40,
#  'public_transport_station_km': 39,
#  'industrial_km': 33,
#  'metro_min_avto': 31,
#  'sub_area': 31,
#  'market_shop_km': 29,
#  'material': 28,
#  'park_km': 28,
#  'green_zone_km': 27,
#  'fitness_km': 26,
#  'school_km': 25,
#  'kindergarten_km': 25,
#  'metro_min_walk': 24}

# %% [markdown]
# Listed above is the 20 attributes scored highest on influencing the price_doc feature. The list is quite rational as it includes all our manually selected features we predicted to be highly influential. The additionally listed features such as the square area of the kitchen and the distance to various utilities are intuitive to be very influential. The remaining features to be used in data exploration will be selected from the above list. Features that will not be included are metro_min_walk as its similarity to metro_min_avto would be redundent their relation to the house prices. Kindergarten_km will also be excluded for it's similarity to school_km.
#
# The below plot describes the attribute importances.

# %%
importanceDf = pd.Series(importance)

fig, ax = plt.subplots(figsize=(10,8))

b = sns.barplot(y=importanceDf.keys(), x=importanceDf,orient='h', ax=ax, color='#3498db')
b.set_yticklabels(importanceDf.keys())
plt.show()

# %% [markdown]
# ### XBG Classifier Attributes Selected
# `public_transport_station_km` Distance to walk to nearest public transport station
#
# `industrial_km` Distance to industrial zone
#
# `metro_min_avto` Distance to drive to subway station
#
# `market_shop_km` Distance to markets/department stores
#
# `material` Enumerated material type for the buildings. Enumeration corresponds to "Panel", "Brick", "Wood", "Mass Concrete", "Breeze Blocks" and "Mass Concrete plus Brick"
#
# `park_km` Distance to park
#
# `green_zone_km` Distance to greenery
#
# `school_km` Distance to school

# %% [markdown]
# #### Selecting Attributes
#
# Here we create a DataFrame with the selected attributes for data exploration and visualisation.

# %%
df_exp = df[["timestamp", "price_doc", "full_sq", "sub_area", "num_room", "build_year", "state", 
             "public_transport_station_km", "industrial_km", "metro_min_avto", 
             "market_shop_km", "material", "park_km", "green_zone_km", "school_km"]]

# %% [markdown]
# ### 1.4. Statistical Information

# %% [markdown]
# #### Measures of Central Tendency
#
# Mean Median Midrange Mode | Median Approximation

# %%
df_exp.describe()
# Out:
#           price_doc       full_sq      num_room    build_year         state  \
# count  3.047100e+04  38133.000000  28561.000000  2.347900e+04  23880.000000
# mean   7.123035e+06     54.111172      1.900844  2.716785e+03      2.071650
# std    4.780111e+06     35.171162      0.847620  1.308521e+05      0.864795
# min    1.000000e+05      0.000000      0.000000  0.000000e+00      1.000000
# 25%    4.740002e+06     38.900000      1.000000  1.966000e+03      1.000000
# 50%    6.274411e+06     50.000000      2.000000  1.980000e+03      2.000000
# 75%    8.300000e+06     63.000000      2.000000  2.006000e+03      3.000000
# max    1.111111e+08   5326.000000     19.000000  2.005201e+07     33.000000
#
#        public_transport_station_km  industrial_km  metro_min_avto  \
# count                 38133.000000   38133.000000    38133.000000
# mean                      0.424452       0.767431        4.902702
# std                       1.352674       0.742974        6.473965
# min                       0.002804       0.000000        0.000000
# 25%                       0.102853       0.286587        1.719313
# 50%                       0.162834       0.571575        2.769542
# 75%                       0.279753       1.040324        4.788853
# max                      17.413002      14.048162       65.101125
#
#        market_shop_km      material       park_km  green_zone_km     school_km
# count    38133.000000  28561.000000  38133.000000   38133.000000  38133.000000
# mean         3.937603      1.834390      3.064809       0.301410      1.347122
# std          3.477093      1.490923      3.915439       0.293917      3.159086
# min          0.003847      1.000000      0.003737       0.000000      0.000000
# 25%          1.540511      1.000000      0.964876       0.103223      0.273073
# 50%          2.887683      1.000000      1.787349       0.216846      0.480208
# 75%          5.439734      2.000000      3.304260       0.420417      0.899203
# max         41.103651      6.000000     47.351538       2.036755     47.394706

# %%
def median_approximation(values, num_intervals=5):
    values_min = min(values)
    values_max = max(values)
    values_range = values_max - values_min
    
    # Determine the range of each interval 
    if isinstance(values[0], int):
        interval_range = values_range // (num_intervals)
    elif isinstance(values[0], float):
        interval_range = values_range / (num_intervals)
    else:
        print("Error: datatype of elements within the passed array is not 'int' or 'float'")
        return -1
        
    # Dictionary mapping interval number to interval range
    interval_ranges = {}  
    
    # Dictionary mapping interval number to values falling within the interval range
    interval_values = {}  
    
    # Determine the range for each interval
    for i in range(num_intervals):
        
        # First interval
        if i == 0:
            interval_ranges[i] = (values_min, values_min + interval_range)
        
        # Last interval
        elif i == num_intervals - 1:
            interval_ranges[i] = (values_min + (i * interval_range), values_max + 1)
            
        # Middle interval
        else:
            interval_ranges[i] = (values_min + (i * interval_range), values_min + ((i + 1) * interval_range))
            
        # Set initial frequency count of interval
        interval_values[i] = 0
            
    # Determine the frequency of values that fall within each interval
    for v in values:
        for i, i_range in interval_ranges.items():
            if i_range[0] <= v < i_range[1]:
                interval_values[i] += 1
                break
    
    # Calculate the median approximation formula components
    median_interval = num_intervals // 2
    sum_lower_freq = sum([interval_values[i] for i in range(0, median_interval)])
    freq_median = interval_values[median_interval]
    width = interval_ranges[median_interval][1] - interval_ranges[median_interval][0]
    L1 = interval_ranges[median_interval][0]
    N = len(values)
    
    # Calculate the median approximation
    median_approx = L1 + ((N/2 - sum_lower_freq) / freq_median) * width
    
    return median_approx

# %%
nums = [random.randint(0, 100) for x in range(10000)]
print("Statistics library median function: {:.2f}".format(statistics.median(nums)))
print("Median approximation: {:.2f}".format(median_approximation(nums)))
# Out:
# Statistics library median function: 50.00
# Median approximation: 51.26

# %% [markdown]
# #### Five-Number Summary
#
# Range, min, quartiles, median max, variance, standard deviation

# %% [markdown]
# ## 2. Data Pre-Processing

# %% [markdown]
# ### Data Quality
# Raw data generally isn't initially suitable for data mining. Poor data quality can dramatically reduce accuracy and lead to incorrect conclusions. Data quality may be affected by the introduction of noise from incorrect data entry or erroneous data from sensors. Outliers skew the distribution of attributes and missing values make it more difficult do get an accuracte representation of the model behind the data. The easiest method for dealing with outliers and missing values is to simply delete/drop them from the dataframe. This provides convenience at the expense of statistical significance due to smaller sample sizes. Therefore, where values are predictable/computatble, we apply methods which replace these values.
# #### Data Mechanism
# In our data preprocessing we make the assumption that the data is 'Missing at Random', such that missing values are independent of other attributes.

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', inplace=True, ascending=False)

f, ax = plt.subplots(figsize=(10, 15))
# missing_value_df = missing_value_df.astype(int)
sns.barplot(missing_value_df.percent_missing[0:60], missing_value_df.column_name[0:60], color="salmon", ax=ax)
plt.show()

# %% [markdown]
# The floor attribute can be seen to be not missing many values from the above graph. The statement below demonstrates that wherever the floor value is null, the max_floor attribute is also null. This would make it likely that these houses are a part of buildings with 1 floor. This data will be cleaned by filling these values with 1.

# %%
(df.floor.isnull() == (df.floor.isnull()) & (df.max_floor.isnull())).value_counts()
# Out:
# True    38133
# dtype: int64

# %% [markdown]
# The state attribute ranges from 1-4, with 1 being poor condition and 4 being the highest condition.
# We need to check for data outside this range.

# %%
(df.loc[(df['state'] > 4) | (df['state'] < 1) ,'state'])
# Out:
# count    23880.000000
# mean         2.070352
# std          0.841315
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          4.000000
# Name: state, dtype: float64

# %% [markdown]
# Only 1 case outside the range was found, with a state of 33. We'll set this to a median value of 2.

# %%
df.loc[df['state'] > 4,'state'] = 2

# %%
df.loc[df.floor.isnull(),'floor'] = 1
df.loc[df.floor.isnull(),'max_floor'] = 1

# %%
df.loc[df.state > 4]["state"]
# Out:
# 10089    33.0
# Name: state, dtype: float64

# %%
df.drop(df[df.state > 4].index, inplace=True)

# %%
df.loc[(df["build_year"] > 2019) | (df.build_year < 300)]
# Out:
#           id   timestamp  full_sq  life_sq  floor  max_floor  material  \
# 9441    9444  2013-07-25    73.00     73.0    5.0       22.0       1.0
# 9620    9623  2013-08-05    65.00     35.0    7.0       12.0       1.0
# 9700    9703  2013-08-08    60.00      NaN   24.0       24.0       1.0
# 9745    9748  2013-08-09    39.00     39.0   10.0       17.0       1.0
# 9764    9767  2013-08-12   119.00      NaN   24.0        1.0       1.0
# ...      ...         ...      ...      ...    ...        ...       ...
# 38111  38114  2016-05-23    77.51      1.0    4.0        1.0       1.0
# 38119  38122  2016-05-23    33.89      1.0    3.0        1.0       1.0
# 38124  38127  2016-05-25    19.91      1.0    8.0        1.0       1.0
# 38125  38128  2016-05-25    23.56      1.0    1.0        1.0       1.0
# 38130  38133  2016-05-30    41.08      1.0   12.0        1.0       1.0
#
#        build_year  num_room  kitch_sq  ...  cafe_count_5000_price_2500  \
# 9441          0.0       3.0       0.0  ...                           1
# 9620          1.0       2.0       1.0  ...                          10
# 9700          1.0       2.0       1.0  ...                           1
# 9745          1.0       1.0      12.0  ...                           1
# 9764          1.0       1.0       1.0  ...                          11
# ...           ...       ...       ...  ...                         ...
# 38111         1.0       3.0       1.0  ...                         371
# 38119         1.0       1.0       1.0  ...                         298
# 38124         1.0       1.0       1.0  ...                         298
# 38125         1.0       1.0       1.0  ...                           0
# 38130         1.0       1.0       1.0  ...                         371
#
#       cafe_count_5000_price_4000 cafe_count_5000_price_high  \
# 9441                           1                          0
# 9620                           3                          0
# 9700                           1                          0
# 9745                           0                          0
# 9764                           2                          1
# ...                          ...                        ...
# 38111                        141                         26
# 38119                         98                         16
# 38124                         98                         16
# 38125                          0                          0
# 38130                        141                         26
#
#        big_church_count_5000  church_count_5000  mosque_count_5000  \
# 9441                       1                  7                  0
# 9620                      10                  9                  0
# 9700                       1                  7                  0
# 9745                       2                  3                  0
# 9764                       5                  4                  0
# ...                      ...                ...                ...
# 38111                    150                249                  2
# 38119                    130                228                  2
# 38124                    130                228                  2
# 38125                      0                  4                  0
# 38130                    150                249                  2
#
#        leisure_count_5000  sport_count_5000  market_count_5000   price_doc
# 9441                    0                 6                  0   5626933.0
# 9620                    0                38                  4   5415070.0
# 9700                    0                 6                  0   5402275.0
# 9745                    0                 6                  1   3984760.0
# 9764                    1                32                  5  15696466.0
# ...                   ...               ...                ...         ...
# 38111                 105               203                 13         NaN
# 38119                  89               185                 14         NaN
# 38124                  89               185                 14         NaN
# 38125                   0                 0                  2         NaN
# 38130                 105               203                 13         NaN
#
# [1462 rows x 292 columns]

# %%
df.drop(df[(df.build_year > 2019) | (df.build_year < 300)].index, inplace=True)

# %% [markdown]
# #### house with full_sq over 5000 while life_sq is 22

# %%
df.loc[df.full_sq > 3000]
df.drop(df[df.full_sq > 3000].index, inplace=True)

# %% [markdown]
# #### house with life_sq of 7478 while full_sq is 79

# %%
df.loc[df.life_sq > 3000]
df.drop(df[df.life_sq > 3000].index, inplace=True)

# %%
# Check for places full_sq and life_sq vary greatly
df[(df.full_sq - df.life_sq).abs() > 300]
# Out:
#           id   timestamp  full_sq  life_sq  floor  max_floor  material  \
# 1478    1481  2012-03-11    353.0     20.0    5.0        NaN       NaN
# 1610    1613  2012-03-21    394.0     17.0   11.0        NaN       NaN
# 2425    2428  2012-06-07    412.0     17.0    6.0        NaN       NaN
# 2780    2783  2012-07-06    729.0     44.0   12.0        NaN       NaN
# 4385    4388  2012-10-25     73.0    426.0   17.0        NaN       NaN
# 5944    5947  2013-02-07    634.0     38.0    3.0        NaN       NaN
# 7207    7210  2013-04-10    461.0     27.0    2.0        NaN       NaN
# 9256    9259  2013-07-17     77.0    458.0   12.0       16.0       1.0
# 9646    9649  2013-08-06     82.0    802.0    5.0        NaN       NaN
# 26342  26345  2014-12-12     75.0    435.0    3.0       22.0       1.0
# 31072  31075  2015-08-17     74.2    742.0    2.0       17.0       1.0
#
#        build_year  num_room  kitch_sq  ...  cafe_count_5000_price_4000  \
# 1478          NaN       NaN       NaN  ...                           2
# 1610          NaN       NaN       NaN  ...                           1
# 2425          NaN       NaN       NaN  ...                          36
# 2780          NaN       NaN       NaN  ...                           5
# 4385          NaN       NaN       NaN  ...                           8
# 5944          NaN       NaN       NaN  ...                           4
# 7207          NaN       NaN       NaN  ...                           2
# 9256       1996.0       3.0      10.0  ...                           0
# 9646          NaN       NaN       NaN  ...                           1
# 26342      1999.0       3.0       9.0  ...                           3
# 31072         NaN       2.0       1.0  ...                           2
#
#       cafe_count_5000_price_high big_church_count_5000  church_count_5000  \
# 1478                           0                     3                  9
# 1610                           0                     8                 23
# 2425                           5                    14                 34
# 2780                           1                     5                 24
# 4385                           0                    14                 25
# 5944                           0                     8                 12
# 7207                           0                     8                 25
# 9256                           0                     5                 22
# 9646                           0                     7                 16
# 26342                          1                     5                  6
# 31072                          0                     3                 12
#
#        mosque_count_5000  leisure_count_5000  sport_count_5000  \
# 1478                   0                   1                14
# 1610                   0                   3                55
# 2425                   1                   6                92
# 2780                   1                   4                63
# 4385                   0                   3                88
# 5944                   1                   0                40
# 7207                   0                   6                56
# 9256                   0                   0                18
# 9646                   0                   0                34
# 26342                  0                   1                32
# 31072                  0                   0                 6
#
#        market_count_5000   price_doc  sub_area_rank
# 1478                   2   4750000.0             30
# 1610                   9   1050000.0             48
# 2425                   5   6117000.0            106
# 2780                   6  13250000.0            128
# 4385                  14  11918400.0            118
# 5944                   5  10200000.0             68
# 7207                   9   5750000.0             56
# 9256                   7  13750000.0             98
# 9646                   5  12031350.0             71
# 26342                  4  12900000.0            107
# 31072                  3         NaN             20
#
# [11 rows x 293 columns]

# %% [markdown]
# #### 1 house is worth 111, 111, 112

# %%
df.loc[df.price_doc == 111111112.0]["price_doc"]
# Out:
# 2118    111111112.0
# Name: price_doc, dtype: float64

# %%
# df.groupby("build_year")["price_doc"].mean().reset_index()
df1 = df.groupby("build_year")["price_doc"]
for key, item in df1:
    print(df1.get_group(key))
# Out:
# 26332    6250000.0
# Name: price_doc, dtype: float64
# 14158    6200000.0
# 27751    2000000.0
# Name: price_doc, dtype: float64
# 35079   NaN
# Name: price_doc, dtype: float64
# 17212    10950000.0
# Name: price_doc, dtype: float64
# 29517    42300000.0
# Name: price_doc, dtype: float64
# 18079    10850000.0
# 18933    24267600.0
# 19541     1200000.0
# 23117     9000000.0
# 23174    12500000.0
# 34357           NaN
# 37938           NaN
# Name: price_doc, dtype: float64
# 16581    2000000.0
# 32012          NaN
# Name: price_doc, dtype: float64
# 12068    11000000.0
# 15282     9700000.0
# Name: price_doc, dtype: float64
# 37822   NaN
# Name: price_doc, dtype: float64
# 17296    27000000.0
# 22778    61072000.0
# Name: price_doc, dtype: float64
# 34071   NaN
# Name: price_doc, dtype: float64
# 21897    35000000.0
# Name: price_doc, dtype: float64
# 28821    26800000.0
# 31442           NaN
# Name: price_doc, dtype: float64
# 22665    21500000.0
# 35353           NaN
# Name: price_doc, dtype: float64
# 8056      2750000.0
# 17582    10400000.0
# Name: price_doc, dtype: float64
# 35352   NaN
# Name: price_doc, dtype: float64
# 15306    27000000.0
# 19394     9200000.0
# 19514     8176000.0
# 28622    29700000.0
# 29225    10020078.0
# 36160           NaN
# Name: price_doc, dtype: float64
# 12225    14900000.0
# 33042           NaN
# 33130           NaN
# 33412           NaN
# Name: price_doc, dtype: float64
# 11043     7360000.0
# 12560    15500000.0
# 19054     9590000.0
# 19708    41000000.0
# 20219    10000000.0
# 33613           NaN
# Name: price_doc, dtype: float64
# 14870    26000000.0
# 29656    70000000.0
# 30440    10000000.0
# 32223           NaN
# 32234           NaN
# Name: price_doc, dtype: float64
# 11430     9050000.0
# 24570    15200000.0
# 26900     8250000.0
# 29284     9950000.0
# 29508    15500000.0
# Name: price_doc, dtype: float64
# 8933     22800000.0
# 10913     3000000.0
# 11278     6500000.0
# 15239    18800000.0
# 16226     2200000.0
# 16907    11200000.0
# 17402    35905920.0
# 17505    22350000.0
# 19691    14600000.0
# 22037    17250000.0
# 22664    23700000.0
# 25117    18500000.0
# 26650    19000000.0
# 27753    19000000.0
# 28969    43000000.0
# 30050    13200000.0
# 32274           NaN
# 35922           NaN
# 35985           NaN
# Name: price_doc, dtype: float64
# 19063    9350000.0
# Name: price_doc, dtype: float64
# 12450     9400000.0
# 17506    24500000.0
# 24085    12500000.0
# 37447           NaN
# Name: price_doc, dtype: float64
# 11673    9200000.0
# Name: price_doc, dtype: float64
# 12993    11000000.0
# 14360    11300000.0
# 14438      999990.0
# 23438    18200000.0
# 24810    14300000.0
# 28117    12700000.0
# 28273    10000000.0
# 29470     3170000.0
# 31104           NaN
# 32165           NaN
# 33714           NaN
# 34563           NaN
# 35031           NaN
# 36668           NaN
# 36822           NaN
# 37188           NaN
# Name: price_doc, dtype: float64
# 11819    10400000.0
# 14778    11700000.0
# 16611    34800000.0
# 16713     1000000.0
# 17908    13300000.0
# 23498     6500000.0
# 23689    13000000.0
# 26242    15000000.0
# 27079    13000000.0
# 28326    95122496.0
# 32861           NaN
# 37445           NaN
# 37573           NaN
# Name: price_doc, dtype: float64
# 11351    15325000.0
# 12282    32500000.0
# 13286    13350000.0
# 14641     1000000.0
# 15939    12700000.0
# 18393     8104000.0
# 21025    11000000.0
# 21130    18420000.0
# 21312    14500000.0
# 22428    12500000.0
# 22692    15750000.0
# 28196    15430000.0
# 30710           NaN
# 31151           NaN
# 31517           NaN
# 32202           NaN
# 33855           NaN
# 35319           NaN
# Name: price_doc, dtype: float64
# 11052     7130000.0
# 11115    15500000.0
# 12152    16900000.0
# 12428    10500000.0
# 13628    14400000.0
# 16308    18700000.0
# 18404    12400000.0
# 22393    16000000.0
# 22633     7000000.0
# 24007    15400000.0
# 25099    21600000.0
# 29939     7000000.0
# 31123           NaN
# 32535           NaN
# 33307           NaN
# 33897           NaN
# Name: price_doc, dtype: float64
# 10901    15000000.0
# 12238    14800000.0
# 17440    15900000.0
# 20013    13500000.0
# 26520     6900000.0
# 26820    13800000.0
# 34014           NaN
# 34837           NaN
# 37865           NaN
# Name: price_doc, dtype: float64
# 13782    13600000.0
# 15808    17700000.0
# 18664    11000000.0
# 19284    14000000.0
# 23044    20079000.0
# 30406    16400000.0
# 33118           NaN
# 37312           NaN
# 37377           NaN
# Name: price_doc, dtype: float64
# 9602      3000000.0
# 11537    15200000.0
# 12079    14900000.0
# 13663    18000000.0
# 14599     8700000.0
# 15543     6900000.0
# 18163    10000000.0
# 23641     7300000.0
# 30744           NaN
# 32045           NaN
# 36475           NaN
# Name: price_doc, dtype: float64
# 10587     9590000.0
# 14965    16500000.0
# 15032     3500000.0
# 15739     7400000.0
# 19071    18500000.0
# 23598     6900000.0
# 28517    11700000.0
# 30999           NaN
# Name: price_doc, dtype: float64
# 9951      8300000.0
# 10839    13300000.0
# 13148     8300000.0
# 14016    12790000.0
# 16489    13200000.0
# 16678    10121000.0
# 18574     6300000.0
# 20070     9000000.0
# 21165    12500000.0
# 24396    18000000.0
# 26237    10150000.0
# 27282    10700000.0
# 27475    10600000.0
# Name: price_doc, dtype: float64
# 9978     19500000.0
# 12872     2000000.0
# 15425     9600000.0
# 15790     3000000.0
# 18459    12500000.0
# 19726    10900000.0
# 22334    13200000.0
# 26068    19900000.0
# 29338     3000000.0
# 29903    12000000.0
# 30467    25000000.0
# 34688           NaN
# Name: price_doc, dtype: float64
# 11433     7750000.0
# 11972    15000000.0
# 12455    13270000.0
# 14483     5800000.0
# 18990    25500000.0
# Name: price_doc, dtype: float64
# 9643      7200000.0
# 12104    14500000.0
# 13184    11200000.0
# 14238    12500000.0
# 14344    15500000.0
# 17705    15520800.0
# 23089    14950000.0
# 24023    14950000.0
# 26666    18000000.0
# 26882    16900000.0
# 30922           NaN
# 32037           NaN
# 34276           NaN
# 35677           NaN
# 37948           NaN
# Name: price_doc, dtype: float64
# 9694      3000000.0
# 19653     8400000.0
# 22282    10650000.0
# 22864    28300000.0
# 24265    16750000.0
# 24433    14500000.0
# 26128    15800000.0
# 26699    17700000.0
# 28102    12000000.0
# 33631           NaN
# 36129           NaN
# 37147           NaN
# Name: price_doc, dtype: float64
# 9737      3000000.0
# 12462    21850000.0
# 12638    17000000.0
# 14487     9000000.0
# 20455    14000000.0
# 21143    12000000.0
# 22077    15550000.0
# 31671           NaN
# 32073           NaN
# 37866           NaN
# Name: price_doc, dtype: float64
# 11732    11900000.0
# 13099    22000000.0
# 15981     8000000.0
# 19141    12800000.0
# 19873    17950000.0
# 20069    12000000.0
# 21605    24400000.0
# 22381    22500000.0
# 23602     2000000.0
# 26487    35000000.0
# 27132     9250000.0
# 27891    23150000.0
# 28194    18700000.0
# 29247    11000000.0
# 32251           NaN
# 34065           NaN
# 34364           NaN
# 35587           NaN
# 37563           NaN
# Name: price_doc, dtype: float64
# 24233     5000000.0
# 24900    12100000.0
# 32461           NaN
# 36773           NaN
# Name: price_doc, dtype: float64
# 36748   NaN
# Name: price_doc, dtype: float64
# 11738     8000000.0
# 13593    24000000.0
# 31168           NaN
# Name: price_doc, dtype: float64
# 33343   NaN
# Name: price_doc, dtype: float64
# 8929     19100000.0
# 13357    15300000.0
# Name: price_doc, dtype: float64
# 10271     8800000.0
# 11952    13300000.0
# 14493    13000000.0
# 22689    11900000.0
# Name: price_doc, dtype: float64
# 16906    18000000.0
# 31382           NaN
# Name: price_doc, dtype: float64
# 14314    10400000.0
# 19271    16700000.0
# 23157    10700000.0
# 36641           NaN
# Name: price_doc, dtype: float64
# 9351     15400000.0
# 9696      7750000.0
# 13485     6000000.0
# 15465     6650000.0
# 16784     8100000.0
# 17001    12000000.0
# 17926    11000000.0
# 18059     5500000.0
# 20181    10800000.0
# 20443    22000000.0
# 21948    10900000.0
# 23379     9100000.0
# 25466    10500000.0
# 25973     7200000.0
# 26530    12400000.0
# 26625    13500000.0
# 27510    14250000.0
# 28834     6550000.0
# 29441     4850000.0
# 29491     8900000.0
# 30047    10500000.0
# 30129    14000000.0
# 31416           NaN
# 31465           NaN
# 31477           NaN
# 34210           NaN
# 36622           NaN
# 37853           NaN
# Name: price_doc, dtype: float64
# 9144      5800000.0
# 11140     9400000.0
# 11585     9800000.0
# 12788    17800000.0
# 14056    14200000.0
# 14375    10200000.0
# 17158     6200000.0
# 17336     1000000.0
# 19385    11700000.0
# 19764     5500000.0
# 23177    11200000.0
# 23536    19500000.0
# 23571     9200000.0
# 24243     4000000.0
# 24532    13900000.0
# 24550     5500000.0
# 26657      999000.0
# 27734     9000000.0
# 28267     2000000.0
# 28583    10950000.0
# 28680    14900000.0
# 29080    11900000.0
# 30143    16000000.0
# 30963           NaN
# 31269           NaN
# 31399           NaN
# 32072           NaN
# 32431           NaN
# 33808           NaN
# 34432           NaN
# 35892           NaN
# 37911           NaN
# Name: price_doc, dtype: float64
# 12653    15300000.0
# 13592    13500000.0
# 13846     2000000.0
# 13988     4000000.0
# 15000     6900000.0
# 16131     6480000.0
# 16341    10800000.0
# 17343    10500000.0
# 17421     2500000.0
# 18053    15000000.0
# 19150     6700000.0
# 20791     9300000.0
# 22503     3000000.0
# 22558     5500000.0
# 22954     8050000.0
# 22973     8500000.0
# 23441     2000000.0
# 23884     2000000.0
# 23888     2000000.0
# 23905     2000000.0
# 24146     2000000.0
# 24251     2000000.0
# 24269    14990000.0
# 24499     2000000.0
# 24504    14000000.0
# 24962    11730000.0
# 24984     2000000.0
# 25071     2000000.0
# 25333    11750000.0
# 25423     2000000.0
# 25639     2000000.0
# 26078     2050000.0
# 26099     2000000.0
# 26246     2000000.0
# 26818     2000000.0
# 27087     2000000.0
# 27491     2000000.0
# 27661     2000000.0
# 27666     8250000.0
# 27826    21500000.0
# 28044    18300000.0
# 28375     2000000.0
# 28860     9000000.0
# 29076    12350000.0
# 29630     2000000.0
# 31966           NaN
# 32047           NaN
# 33255           NaN
# 34591           NaN
# 35653           NaN
# 36512           NaN
# Name: price_doc, dtype: float64
# 10570    10500000.0
# 11162     9200000.0
# 11229     9750000.0
# 12092     8000000.0
# 13068    17500000.0
# 13119    13700000.0
# 13718     6860000.0
# 14436    16500000.0
# 17110    12400000.0
# 18190    14500000.0
# 18202    10400000.0
# 19336    13800000.0
# 19731     2000000.0
# 19834    13500000.0
# 21180    14600000.0
# 23101    11500000.0
# 23698    10500000.0
# 24000     3900000.0
# 24118    18000000.0
# 24355    11800000.0
# 24566     5900000.0
# 25823    22500000.0
# 25884    22500000.0
# 29557     8250000.0
# 31826           NaN
# 33037           NaN
# 34083           NaN
# 34483           NaN
# 34610           NaN
# 34991           NaN
# 35429           NaN
# 35738           NaN
# 35967           NaN
# 35980           NaN
# 36186           NaN
# 36461           NaN
# 36932           NaN
# 38107           NaN
# Name: price_doc, dtype: float64
# 9110     11500000.0
# 10497     9000000.0
# 10775     6300000.0
# 11561     6750000.0
# 11623    14600000.0
# 12272    29000000.0
# 12659    11300000.0
# 13004     8600000.0
# 13463    11970000.0
# 15969     6700000.0
# 17163    10600000.0
# 17172    14000000.0
# 18025     9800000.0
# 18206     9900000.0
# 18720    11600000.0
# 18889    20250000.0
# 20377    10700000.0
# 20460     3000000.0
# 20590     4700000.0
# 20602    11200000.0
# 21049     1000000.0
# 22239    14800000.0
# 22519    11500000.0
# 23056     8333000.0
# 23759    17000000.0
# 23820     4000000.0
# 23833     8400000.0
# 25578     9500000.0
# 25638    13300000.0
# 27698    16000000.0
# 28385    44000000.0
# 28409    13450000.0
# 29045     8100000.0
# 29472    10200000.0
# 29662    12600000.0
# 30325    12000000.0
# 32168           NaN
# 32533           NaN
# 33794           NaN
# 34734           NaN
# 36780           NaN
# 36836           NaN
# 37534           NaN
# 37707           NaN
# Name: price_doc, dtype: float64
# 9170     10500000.0
# 10677    11550000.0
# 11067    31000000.0
# 11242     9900000.0
# 11267    11150000.0
#             ...
# 35867           NaN
# 36169           NaN
# 36435           NaN
# 37466           NaN
# 38072           NaN
# Name: price_doc, Length: 66, dtype: float64
# 9361     14000000.0
# 9387     18000000.0
# 10578    18250000.0
# 11754    28000000.0
# 12814    10400000.0
#             ...
# 36806           NaN
# 37092           NaN
# 37406           NaN
# 37760           NaN
# 37775           NaN
# Name: price_doc, Length: 65, dtype: float64
# 8287     11700000.0
# 8795     10300000.0
# 9126     16100000.0
# 9457      3000000.0
# 9872      5000000.0
#             ...
# 37125           NaN
# 37165           NaN
# 37305           NaN
# 37347           NaN
# 37588           NaN
# Name: price_doc, Length: 155, dtype: float64
# 8818     16000000.0
# 8906     17500000.0
# 9072     10000000.0
# 9520     17000000.0
# 9525     12700000.0
#             ...
# 37508           NaN
# 37549           NaN
# 37564           NaN
# 37596           NaN
# 37740           NaN
# Name: price_doc, Length: 232, dtype: float64
# 8721      8700000.0
# 9521      2000000.0
# 9552     15100000.0
# 9899     14500000.0
# 9916      7025000.0
#             ...
# 37387           NaN
# 37388           NaN
# 37552           NaN
# 37965           NaN
# 38102           NaN
# Name: price_doc, Length: 288, dtype: float64
# 8350     6400000.0
# 8410     5950000.0
# 8903     6300000.0
# 9114     1000000.0
# 9270     5650000.0
#            ...
# 37432          NaN
# 37649          NaN
# 37738          NaN
# 37953          NaN
# 37999          NaN
# Name: price_doc, Length: 462, dtype: float64
# 8501      7300000.0
# 8761     14500000.0
# 8894      6800000.0
# 8897      3000000.0
# 9027      4700000.0
#             ...
# 37463           NaN
# 37467           NaN
# 37555           NaN
# 37571           NaN
# 37961           NaN
# Name: price_doc, Length: 399, dtype: float64
# 8391     6200000.0
# 8696     5650000.0
# 8731     6300000.0
# 8740      990000.0
# 8790     3000000.0
#            ...
# 37813          NaN
# 37829          NaN
# 37837          NaN
# 38080          NaN
# 38086          NaN
# Name: price_doc, Length: 449, dtype: float64
# 9034     3900000.0
# 9117     6300000.0
# 9138     4650000.0
# 9204     4300000.0
# 9403     6500000.0
#            ...
# 37731          NaN
# 37746          NaN
# 37755          NaN
# 37843          NaN
# 37958          NaN
# Name: price_doc, Length: 423, dtype: float64
# 8583     6400000.0
# 8652     6775000.0
# 8976     6600000.0
# 8978     8600000.0
# 9066     6500000.0
#            ...
# 37729          NaN
# 37759          NaN
# 37782          NaN
# 37817          NaN
# 37966          NaN
# Name: price_doc, Length: 429, dtype: float64
# 8452     4500000.0
# 8718     6700000.0
# 8727     5900000.0
# 8811     7650000.0
# 9158     1000000.0
#            ...
# 37735          NaN
# 37751          NaN
# 37857          NaN
# 37946          NaN
# 37979          NaN
# Name: price_doc, Length: 487, dtype: float64
# 8535     6700000.0
# 9011     2000000.0
# 9107     6800000.0
# 9703     1000000.0
# 9782     6080000.0
#            ...
# 37950          NaN
# 37964          NaN
# 37974          NaN
# 37978          NaN
# 38044          NaN
# Name: price_doc, Length: 486, dtype: float64
# 8563     5800000.0
# 8577     6900000.0
# 8705     7200000.0
# 9463     1000000.0
# 9583     8500000.0
#            ...
# 37858          NaN
# 37970          NaN
# 37981          NaN
# 38062          NaN
# 38103          NaN
# Name: price_doc, Length: 517, dtype: float64
# 8639     8000000.0
# 8979     8900000.0
# 9181     3800000.0
# 9365     5900000.0
# 9461     6450000.0
#            ...
# 37846          NaN
# 37851          NaN
# 37924          NaN
# 38029          NaN
# 38091          NaN
# Name: price_doc, Length: 526, dtype: float64
# 8423      5900000.0
# 8699      8720000.0
# 8758      5800000.0
# 8825     10000000.0
# 8927      7200000.0
#             ...
# 37889           NaN
# 37893           NaN
# 37940           NaN
# 38008           NaN
# 38021           NaN
# Name: price_doc, Length: 548, dtype: float64
# 8154     7100000.0
# 8638     7250000.0
# 9013     4200000.0
# 9180     1000000.0
# 9448     6000000.0
#            ...
# 37684          NaN
# 37767          NaN
# 37842          NaN
# 37877          NaN
# 38013          NaN
# Name: price_doc, Length: 540, dtype: float64
# 8519     10500000.0
# 8700      9150000.0
# 8966      7000000.0
# 8967      6098000.0
# 9155      5800000.0
#             ...
# 37879           NaN
# 37983           NaN
# 38012           NaN
# 38023           NaN
# 38043           NaN
# Name: price_doc, Length: 485, dtype: float64
# 8427     2000000.0
# 8752     6200000.0
# 9024     5400000.0
# 9245     1000000.0
# 9307     6800000.0
#            ...
# 37819          NaN
# 37840          NaN
# 37859          NaN
# 37864          NaN
# 38053          NaN
# Name: price_doc, Length: 478, dtype: float64
# 9237      5600000.0
# 9536      7500000.0
# 9560     10340000.0
# 9576      4300000.0
# 9581      5550000.0
#             ...
# 37719           NaN
# 37903           NaN
# 37949           NaN
# 38128           NaN
# 38132           NaN
# Name: price_doc, Length: 449, dtype: float64
# 8702     7400000.0
# 9053     2000000.0
# 9118     7100000.0
# 9205     7600000.0
# 9321     5000000.0
#            ...
# 37941          NaN
# 38063          NaN
# 38068          NaN
# 38071          NaN
# 38074          NaN
# Name: price_doc, Length: 466, dtype: float64
# 8374      5100000.0
# 8836      8700000.0
# 9219      6600000.0
# 9350      7880000.0
# 9723     11000000.0
#             ...
# 37544           NaN
# 37656           NaN
# 37675           NaN
# 37734           NaN
# 37881           NaN
# Name: price_doc, Length: 406, dtype: float64
# 8792     1000000.0
# 9025     9150000.0
# 9157     5250000.0
# 9175     7950000.0
# 9547     6200000.0
#            ...
# 37870          NaN
# 37919          NaN
# 37954          NaN
# 37977          NaN
# 38025          NaN
# Name: price_doc, Length: 349, dtype: float64
# 8590     4850000.0
# 8988     1000000.0
# 9062     1000000.0
# 9404     7200000.0
# 9467     5825000.0
#            ...
# 37698          NaN
# 37776          NaN
# 37827          NaN
# 37916          NaN
# 38131          NaN
# Name: price_doc, Length: 356, dtype: float64
# 8525     1000000.0
# 8627     9300000.0
# 9019     8800000.0
# 9067     5350000.0
# 9271     3000000.0
#            ...
# 37654          NaN
# 37671          NaN
# 37677          NaN
# 37763          NaN
# 37808          NaN
# Name: price_doc, Length: 329, dtype: float64
# 8367     7200000.0
# 8499     6000000.0
# 8647     6900000.0
# 8984     8500000.0
# 9167     2000000.0
#            ...
# 37506          NaN
# 37570          NaN
# 37659          NaN
# 37906          NaN
# 37912          NaN
# Name: price_doc, Length: 317, dtype: float64
# 8135     9000000.0
# 8605     2000000.0
# 8643     6100000.0
# 9644     8700000.0
# 9785     7900000.0
#            ...
# 37915          NaN
# 37933          NaN
# 38002          NaN
# 38070          NaN
# 38073          NaN
# Name: price_doc, Length: 308, dtype: float64
# 9152      7200000.0
# 9746      1000000.0
# 9836     13800000.0
# 9877      6250000.0
# 10017     9100000.0
#             ...
# 37812           NaN
# 37849           NaN
# 37955           NaN
# 37998           NaN
# 38033           NaN
# Name: price_doc, Length: 247, dtype: float64
# 8175     6450000.0
# 8719     5700000.0
# 8914     2000000.0
# 9562     6800000.0
# 9573     6600000.0
#            ...
# 37814          NaN
# 37839          NaN
# 37895          NaN
# 37943          NaN
# 38046          NaN
# Name: price_doc, Length: 256, dtype: float64
# 8602      2000000.0
# 8746     12200000.0
# 9482      3000000.0
# 9651      7349000.0
# 9938      7100000.0
#             ...
# 37670           NaN
# 37799           NaN
# 37971           NaN
# 38026           NaN
# 38065           NaN
# Name: price_doc, Length: 265, dtype: float64
# 8774     9900000.0
# 9124     7000000.0
# 9890     9300000.0
# 9984     6700000.0
# 10431    5000000.0
#            ...
# 37638          NaN
# 37749          NaN
# 37815          NaN
# 37932          NaN
# 38105          NaN
# Name: price_doc, Length: 222, dtype: float64
# 8476      6600000.0
# 8513      3000000.0
# 8576      8500000.0
# 8686     10500000.0
# 9527      9000000.0
#             ...
# 37664           NaN
# 37727           NaN
# 37756           NaN
# 38069           NaN
# 38079           NaN
# Name: price_doc, Length: 243, dtype: float64
# 8293      1600000.0
# 8729      5450000.0
# 9444     19900000.0
# 9747     12000000.0
# 9926      6800000.0
#             ...
# 37456           NaN
# 37645           NaN
# 37676           NaN
# 37742           NaN
# 37882           NaN
# Name: price_doc, Length: 185, dtype: float64
# 8387     10400000.0
# 8557     14500000.0
# 9335      8200000.0
# 9352      9550000.0
# 9392     14100000.0
#             ...
# 37041           NaN
# 37234           NaN
# 37311           NaN
# 37669           NaN
# 37942           NaN
# Name: price_doc, Length: 232, dtype: float64
# 8822     12500000.0
# 9691      7500000.0
# 10407     5650000.0
# 10453     9700000.0
# 10494     8500000.0
#             ...
# 37203           NaN
# 37273           NaN
# 37468           NaN
# 37577           NaN
# 37705           NaN
# Name: price_doc, Length: 226, dtype: float64
# 8813      8300000.0
# 10292     7500000.0
# 10320     6300000.0
# 10425    14000000.0
# 10772     2800000.0
#             ...
# 37602           NaN
# 37743           NaN
# 37801           NaN
# 37914           NaN
# 38015           NaN
# Name: price_doc, Length: 196, dtype: float64
# 8883      8500000.0
# 10011    10350000.0
# 10226     7150000.0
# 10241     1000000.0
# 10417     4500000.0
#             ...
# 37472           NaN
# 37752           NaN
# 37894           NaN
# 38016           NaN
# 38028           NaN
# Name: price_doc, Length: 174, dtype: float64
# 9838      7400000.0
# 10654     4700000.0
# 11294    11200000.0
# 11429     5900000.0
# 11500     1000000.0
#             ...
# 36518           NaN
# 36851           NaN
# 37138           NaN
# 37166           NaN
# 37352           NaN
# Name: price_doc, Length: 121, dtype: float64
# 9332      5500000.0
# 9358      8500000.0
# 9498      6285000.0
# 9618     10400000.0
# 9619      8200000.0
#             ...
# 37518           NaN
# 37674           NaN
# 37714           NaN
# 37781           NaN
# 38011           NaN
# Name: price_doc, Length: 195, dtype: float64
# 8424     11000000.0
# 8962      4600000.0
# 9456     10500000.0
# 9772      6050000.0
# 9859      6500000.0
#             ...
# 37491           NaN
# 37713           NaN
# 37824           NaN
# 37874           NaN
# 37878           NaN
# Name: price_doc, Length: 154, dtype: float64
# 9247     11000000.0
# 9264     11200000.0
# 9302     13200000.0
# 9715      4700000.0
# 9783      8100000.0
#             ...
# 37037           NaN
# 37094           NaN
# 37224           NaN
# 37272           NaN
# 37464           NaN
# Name: price_doc, Length: 209, dtype: float64
# 8362      9100000.0
# 9036      9300000.0
# 9593      7400000.0
# 9603     10500000.0
# 10423    10300000.0
#             ...
# 37098           NaN
# 37109           NaN
# 37211           NaN
# 37492           NaN
# 37494           NaN
# Name: price_doc, Length: 189, dtype: float64
# 8426     10500000.0
# 9014     10200000.0
# 9139      6000000.0
# 9256     13750000.0
# 9586     11800000.0
#             ...
# 37834           NaN
# 37850           NaN
# 37993           NaN
# 38051           NaN
# 38110           NaN
# Name: price_doc, Length: 206, dtype: float64
# 8793      8050000.0
# 8912      3850000.0
# 9535      8700000.0
# 10200     1000000.0
# 10258    11100000.0
#             ...
# 37668           NaN
# 37761           NaN
# 37962           NaN
# 38039           NaN
# 38041           NaN
# Name: price_doc, Length: 197, dtype: float64
# 9259     8300000.0
# 10119    6600000.0
# 10324    8000000.0
# 10359    7300000.0
# 10579    1100000.0
#            ...
# 37306          NaN
# 37350          NaN
# 37370          NaN
# 37378          NaN
# 37904          NaN
# Name: price_doc, Length: 187, dtype: float64
# 9199     14500000.0
# 9500     11800000.0
# 9748      6000000.0
# 10270     8550000.0
# 10384     6200000.0
#             ...
# 37820           NaN
# 37847           NaN
# 37935           NaN
# 37937           NaN
# 38052           NaN
# Name: price_doc, Length: 178, dtype: float64
# 8574     28500000.0
# 8689     11500000.0
# 9930     18000000.0
# 9976      8500000.0
# 10136     5900000.0
#             ...
# 37873           NaN
# 37902           NaN
# 38009           NaN
# 38084           NaN
# 38122           NaN
# Name: price_doc, Length: 186, dtype: float64
# 9007      6500000.0
# 9134      5700000.0
# 9541     13600000.0
# 9678     16000000.0
# 9729     16150000.0
#             ...
# 37359           NaN
# 37365           NaN
# 37582           NaN
# 38031           NaN
# 38076           NaN
# Name: price_doc, Length: 240, dtype: float64
# 8965      6900000.0
# 9250     14000000.0
# 9268     11600000.0
# 9686      6000000.0
# 9735      8600000.0
#             ...
# 37539           NaN
# 37690           NaN
# 37867           NaN
# 37987           NaN
# 38042           NaN
# Name: price_doc, Length: 279, dtype: float64
# 8282      7700000.0
# 8509      5300000.0
# 9198      5650000.0
# 9367      8600000.0
# 9489     15500000.0
#             ...
# 37340           NaN
# 37379           NaN
# 37536           NaN
# 37655           NaN
# 37750           NaN
# Name: price_doc, Length: 254, dtype: float64
# 8255     12100000.0
# 8381     11200000.0
# 8625     10300000.0
# 8953      2000000.0
# 9030      6600000.0
#             ...
# 37615           NaN
# 37633           NaN
# 37708           NaN
# 37783           NaN
# 38100           NaN
# Name: price_doc, Length: 286, dtype: float64
# 8986     21400000.0
# 9193      6650000.0
# 9334      9000000.0
# 9364      1000000.0
# 9523     12500000.0
#             ...
# 37397           NaN
# 37730           NaN
# 37773           NaN
# 37945           NaN
# 38088           NaN
# Name: price_doc, Length: 241, dtype: float64
# 8498     9850000.0
# 8869     2000000.0
# 9172     5600000.0
# 9540     6750000.0
# 9701     3000000.0
#            ...
# 37419          NaN
# 37449          NaN
# 37875          NaN
# 37960          NaN
# 38018          NaN
# Name: price_doc, Length: 334, dtype: float64
# 8759      7600000.0
# 9252      4700000.0
# 9820     11550000.0
# 9924      3000000.0
# 9964      5500000.0
#             ...
# 37689           NaN
# 37768           NaN
# 37871           NaN
# 37930           NaN
# 37968           NaN
# Name: price_doc, Length: 265, dtype: float64
# 8712     11300000.0
# 8829      7700000.0
# 9037      8800000.0
# 9359      2630000.0
# 9450     13300000.0
#             ...
# 37991           NaN
# 37994           NaN
# 38003           NaN
# 38022           NaN
# 38049           NaN
# Name: price_doc, Length: 308, dtype: float64
# 9213      6350000.0
# 9604      8000000.0
# 9796     11000000.0
# 10018    13500000.0
# 10083    15774750.0
#             ...
# 37631           NaN
# 37706           NaN
# 37811           NaN
# 37855           NaN
# 38098           NaN
# Name: price_doc, Length: 234, dtype: float64
# 8470      4569600.0
# 8723      2000000.0
# 9018      5200000.0
# 9567      3700000.0
# 10272    26244908.0
#             ...
# 36998           NaN
# 37581           NaN
# 37601           NaN
# 37696           NaN
# 37928           NaN
# Name: price_doc, Length: 179, dtype: float64
# 8451      2680000.0
# 10063     4500000.0
# 10295    44848000.0
# 10345    17516236.0
# 10535    14173785.0
#             ...
# 37747           NaN
# 37793           NaN
# 37818           NaN
# 37823           NaN
# 38030           NaN
# Name: price_doc, Length: 223, dtype: float64
# 8830      3478200.0
# 9113     10165000.0
# 9437     11460000.0
# 9449      6700000.0
# 9669      7074000.0
#             ...
# 37863           NaN
# 37959           NaN
# 37976           NaN
# 38078           NaN
# 38115           NaN
# Name: price_doc, Length: 307, dtype: float64
# 8186     5903808.0
# 8268     5427640.0
# 8796     5680000.0
# 8856     5930866.0
# 8949     8287230.0
#            ...
# 38010          NaN
# 38020          NaN
# 38034          NaN
# 38048          NaN
# 38114          NaN
# Name: price_doc, Length: 724, dtype: float64
# 8153     7011550.0
# 9257     4309670.0
# 9684     5073100.0
# 9945     3875500.0
# 9956     7221456.0
#            ...
# 37900          NaN
# 37925          NaN
# 37989          NaN
# 38094          NaN
# 38118          NaN
# Name: price_doc, Length: 1117, dtype: float64
# 9412     2473800.0
# 9949     4033260.0
# 9958     5057881.0
# 10153    5347269.0
# 10187    8552548.0
#            ...
# 38005          NaN
# 38036          NaN
# 38050          NaN
# 38066          NaN
# 38112          NaN
# Name: price_doc, Length: 1083, dtype: float64
# 10706     6294780.0
# 10955    10844900.0
# 14531     9410450.0
# 14638     2558485.0
# 14666    12534364.0
#             ...
# 38083           NaN
# 38092           NaN
# 38116           NaN
# 38117           NaN
# 38123           NaN
# Name: price_doc, Length: 775, dtype: float64
# 12934    10677640.0
# 13635     7187460.0
# 13906     7644900.0
# 13949    13480320.0
# 15067    16120620.0
#             ...
# 38082           NaN
# 38090           NaN
# 38101           NaN
# 38108           NaN
# 38121           NaN
# Name: price_doc, Length: 567, dtype: float64
# 29767    18800000.0
# 30923           NaN
# 32473           NaN
# 32530           NaN
# 33025           NaN
# 33066           NaN
# 33181           NaN
# 33539           NaN
# 33608           NaN
# 34326           NaN
# 34743           NaN
# 34872           NaN
# 35115           NaN
# 35886           NaN
# 36789           NaN
# 36871           NaN
# 36924           NaN
# 37005           NaN
# 37082           NaN
# 37513           NaN
# 37603           NaN
# 37692           NaN
# 37717           NaN
# 37723           NaN
# 37835           NaN
# 37897           NaN
# 37905           NaN
# 37963           NaN
# 37995           NaN
# 38007           NaN
# 38099           NaN
# Name: price_doc, dtype: float64
# 33401   NaN
# 34708   NaN
# 37128   NaN
# 37505   NaN
# 38096   NaN
# Name: price_doc, dtype: float64

# %% [markdown]
# ### Outlier Detection

# %%
# Find houses outside +- 3 standard deviations
df[(df.price_doc/df.price_doc.std()).abs() > 3]["price_doc"]
# Out:
# 4        16331452.0
# 31       18300000.0
# 79       17600000.0
# 170      37000000.0
# 185      18000000.0
#             ...
# 30420    16830500.0
# 30434    17200000.0
# 30438    20000000.0
# 30441    25039300.0
# 30467    25000000.0
# Name: price_doc, Length: 1563, dtype: float64

# %% [markdown]
# #### Maximum Likelihood Estimation

# %% [markdown]
# ## 3. Data Visualisation

# %% [markdown]
# ### Bubble Map

# %%
from geopy.geocoders import Nominatim

values = df['sub_area'].value_counts().keys().tolist()
counts = df['sub_area'].value_counts().tolist()

# Normailze counts into the range of 0-100%
s = sum(counts)
market_shares = [c/s for c in counts]

# Capitalise the titles of each district for visualisation
districts = [w.title() for w in values]

# Find the corresponding latitudes and longitudes of the districts
located_districts = []
location_latitudes = []
location_longitudes = []
located_location_sales_count = []
located_location_market_shares = []

geolocator = Nominatim(user_agent='joshua_russell', timeout=10)

for i, location in enumerate(districts):
    loc = geolocator.geocode(location + ", Moscow, Russia")
    
    # Only record data for districts whose latitude and longitude could be found
    if loc is not None:
        located_districts.append(location)
        location_latitudes.append(loc.latitude)
        location_longitudes.append(loc.longitude)
        located_location_sales_count.append(counts[i])
        located_location_market_shares.append(market_shares[i])

# Create a DataFrame to plot the circles on the map
data = pd.DataFrame({
    "lat": location_latitudes,
    "lon": location_longitudes,
    "district": located_districts,
    "market_share": located_location_market_shares,
    "sales_count": located_location_sales_count
})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-691476f0d604> in <module>
#      22
#      23 for i, location in enumerate(districts):
# ---> 24     loc = geolocator.geocode(location + ", Moscow, Russia")
#      25
#      26     # Only record data for districts whose latitude and longitude could be found
#
# ~/.local/lib/python3.6/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     385
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#     389
#
# ~/.local/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     353
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#     357             message = (
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /usr/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/lib/python3.6/urllib/request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316             try:
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
#
# /usr/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /usr/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# /usr/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# /usr/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# /usr/lib/python3.6/http/client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# /usr/lib/python3.6/http/client.py in connect(self)
#    1398
#    1399             self.sock = self._context.wrap_socket(self.sock,
# -> 1400                                                   server_hostname=server_hostname)
#    1401             if not self._context.check_hostname and self._check_hostname:
#    1402                 try:
#
# /usr/lib/python3.6/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     405                          suppress_ragged_eofs=suppress_ragged_eofs,
#     406                          server_hostname=server_hostname,
# --> 407                          _context=self, _session=session)
#     408
#     409     def wrap_bio(self, incoming, outgoing, server_side=False,
#
# /usr/lib/python3.6/ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     815                         # non-blocking
#     816                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 817                     self.do_handshake()
#     818
#     819             except (OSError, ValueError):
#
# /usr/lib/python3.6/ssl.py in do_handshake(self, block)
#    1075             if timeout == 0.0 and block:
#    1076                 self.settimeout(None)
# -> 1077             self._sslobj.do_handshake()
#    1078         finally:
#    1079             self.settimeout(timeout)
#
# /usr/lib/python3.6/ssl.py in do_handshake(self)
#     687     def do_handshake(self):
#     688         """Start the SSL/TLS handshake."""
# --> 689         self._sslobj.do_handshake()
#     690         if self.context.check_hostname:
#     691             if not self.server_hostname:
#
# KeyboardInterrupt:

# %%
# Create an empty map centered at Russia
m = folium.Map(location=[55.7558, 37.6173], zoom_start=10)
 
# Add circles at each location scaled to the market share of the particular location
for i in range(0, len(data)):
   folium.Circle(
      location=[float(data.iloc[i]["lat"]), float(data.iloc[i]["lon"])],
      popup=str("<strong>{}</strong> ({} Home Sales)".format(data.iloc[i]["district"], data.iloc[i]["sales_count"])),
      radius=float(data.iloc[i]["market_share"]*100000),
      color='crimson',
      fill=True,
      fill_color='crimson'
   ).add_to(m)

# Display the map
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Save the map to a HTML file
m.save("Russian-House-Market-Share-Map.html")

# %% [markdown]
# ### full_sq (total area in square meters)
# #### &
# ### life_sq (living area, excluding loggias, balconies and other non-residential areas)

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 6))
sns.distplot(df[df.full_sq.notnull()], ax=ax[0])
sns.distplot(df[df.life_sq.notnull()], ax=ax[1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-3174d19cea54> in <module>
#       1 fig, ax = plt.subplots(1, 2, figsize=(15, 6))
# ----> 2 sns.distplot(df[df.full_sq.notnull()], ax=ax[0])
#       3 sns.distplot(df[df.life_sq.notnull()], ax=ax[1])
#       4 plt.show()
#
# ~/.local/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     196             line, = ax.plot(0, a.mean())
#     197         else:
# --> 198             line, = ax.plot(a.mean(), 0)
#     199         color = line.get_color()
#     200         line.remove()
#
# ~/.local/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     149             is_float16_result = True
#     150
# --> 151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
#     153         ret = um.true_divide(
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(df.price_doc, df.full_sq, ax=ax)
sns.scatterplot(df.price_doc, df.life_sq, ax=ax)
plt.show()

# %% [markdown]
# ### Floor (floor of apartment) and Max Floor (number of floors in building)

# %%
Sub Areaf, ax = plt.subplots(1, 2, figsize=(15, 6))
sns.distplot(df.loc[df.floor.notnull()]["floor"], bins=77, ax=ax[0])
sns.distplot(df.loc[df.max_floor.notnull()]["max_floor"], bins=117, ax=ax[1])
plt.show()

# %%
f, ax = plt.subplots(2, 1, figsize=(14, 10))
sns.scatterplot(x=df.floor, y=df.price_doc, ax=ax[0])
sns.scatterplot(x=df.max_floor, y=df.price_doc, ax=ax[1])
plt.show()

# %% [markdown]
# ### Price_doc (House Sale Price)

# %%
f, ax = plt.subplots(figsize=(15, 6))
sns.distplot(df_train.price_doc, ax=ax)
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 6))
## Price over time
df1 = df.groupby("build_year")["price_doc"].mean().reset_index()
sns.lineplot(df1.build_year, df1.price_doc, ax=ax)
sns.scatterplot(df1.build_year, df1.price_doc, ax=ax)
ax.set_title("Price Over Time")
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 6))
sns.scatterplot(range(df.shape[0]), np.sort(df.price_doc.values), ax=ax)
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 35))
sorted_sub_area = df.groupby("sub_area")["price_doc"].mean().sort_values().reset_index()["sub_area"]
sorterIndex = dict(zip(sorted_sub_area,range(len(sorted_sub_area))))

df['sub_area_rank'] = df['sub_area'].map(sorterIndex)
df.sub_area_rank
df1 = df.sort_values(by='sub_area_rank')
p = sns.scatterplot(y=df1.sub_area, x=df1.price_doc, ax=ax)
p.set_title("Prices per Sub Area")
# p.set_yticklabels(df.sub_area, rotation='90')
plt.show()

# %%
fig, axs = plt.subplots(2,3,figsize=(20,30))
ax_iter = iter(axs.flat)

distList = ['market_shop_km', 'industrial_km', 'public_transport_station_km','park_km','green_zone_km','school_km']
 
for d in distList:
    ax = next(ax_iter)
    ax.set_xlabel("KM")
    ax.set_ylabel("Price")
    ax.set_title(d)
    ax.scatter(x=df[d], y=(df["price_doc"]))

# %% [markdown]
# ### Material (wall material)

# %%
material_names = ["", "Panel", "Brick", "Wood", "Mass Concrete", "Breeze Blocks", "Mass Concrete plus Brick"]

# Plot the distribution of materials
df.material.value_counts().values
v = sns.violinplot(x=df.material)
v.set_xticklabels(material_names, rotation='90')
v.set_title("Overall Material Distribution")
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 20))
sa = df.loc[df.sub_area.isin(df.sub_area.value_counts().keys()[-50:-30])]
# sa = df.iloc[df.groupby('sub_area').sub_area.transform('size').argsort(kind='mergesort')]
v = sns.violinplot(x=sa.material, y=sa.sub_area, ax=ax)
v.set_xticklabels(material_names, rotation='90')
v.set_title("Distribution of Material per Sub Area")
plt.show()

# %%
f, ax = plt.subplots(figsize=(5, 5))
sorted_state = df.groupby("state")["price_doc"].mean().sort_values().reset_index()["state"]
sorterIndex = dict(zip(sorted_state,range(len(sorted_state))))

df['state_rank'] = df['state'].map(sorterIndex)
df1 = df.sort_values(by='state_rank')
p = sns.scatterplot(y=df1.state, x=df1.price_doc, ax=ax)
p.set_title("Prices per State")
plt.show()

# %%
# Out:
# Empty DataFrame
# Columns: [id, timestamp, full_sq, life_sq, floor, max_floor, material, build_year, num_room, kitch_sq, state, product_type, sub_area, area_m, raion_popul, green_zone_part, indust_part, children_preschool, preschool_quota, preschool_education_centers_raion, children_school, school_quota, school_education_centers_raion, school_education_centers_top_20_raion, hospital_beds_raion, healthcare_centers_raion, university_top_20_raion, sport_objects_raion, additional_education_raion, culture_objects_top_25, culture_objects_top_25_raion, shopping_centers_raion, office_raion, thermal_power_plant_raion, incineration_raion, oil_chemistry_raion, radiation_raion, railroad_terminal_raion, big_market_raion, nuclear_reactor_raion, detention_facility_raion, full_all, male_f, female_f, young_all, young_male, young_female, work_all, work_male, work_female, ekder_all, ekder_male, ekder_female, 0_6_all, 0_6_male, 0_6_female, 7_14_all, 7_14_male, 7_14_female, 0_17_all, 0_17_male, 0_17_female, 16_29_all, 16_29_male, 16_29_female, 0_13_all, 0_13_male, 0_13_female, raion_build_count_with_material_info, build_count_block, build_count_wood, build_count_frame, build_count_brick, build_count_monolith, build_count_panel, build_count_foam, build_count_slag, build_count_mix, raion_build_count_with_builddate_info, build_count_before_1920, build_count_1921-1945, build_count_1946-1970, build_count_1971-1995, build_count_after_1995, ID_metro, metro_min_avto, metro_km_avto, metro_min_walk, metro_km_walk, kindergarten_km, school_km, park_km, green_zone_km, industrial_km, water_treatment_km, cemetery_km, incineration_km, railroad_station_walk_km, railroad_station_walk_min, ID_railroad_station_walk, ...]
# Index: []
#
# [0 rows x 293 columns]

# %% [markdown]
# ## Unassigned

# %%
df.timestamp = pd.to_datetime(df.timestamp)
print(f'Time Range:\n{df.timestamp.min()} - {df.timestamp.max()}')

# %%
print(f'Price Range: {df.price_doc.min()} - {df.price_doc.max()}')

# %%
condition = (df.life_sq > df.full_sq)
df.loc[condition, 'full_sq'] = df[condition]["life_sq"]
df[condition]
# Out:
# Empty DataFrame
# Columns: [id, timestamp, full_sq, life_sq, floor, max_floor, material, build_year, num_room, kitch_sq, state, product_type, sub_area, area_m, raion_popul, green_zone_part, indust_part, children_preschool, preschool_quota, preschool_education_centers_raion, children_school, school_quota, school_education_centers_raion, school_education_centers_top_20_raion, hospital_beds_raion, healthcare_centers_raion, university_top_20_raion, sport_objects_raion, additional_education_raion, culture_objects_top_25, culture_objects_top_25_raion, shopping_centers_raion, office_raion, thermal_power_plant_raion, incineration_raion, oil_chemistry_raion, radiation_raion, railroad_terminal_raion, big_market_raion, nuclear_reactor_raion, detention_facility_raion, full_all, male_f, female_f, young_all, young_male, young_female, work_all, work_male, work_female, ekder_all, ekder_male, ekder_female, 0_6_all, 0_6_male, 0_6_female, 7_14_all, 7_14_male, 7_14_female, 0_17_all, 0_17_male, 0_17_female, 16_29_all, 16_29_male, 16_29_female, 0_13_all, 0_13_male, 0_13_female, raion_build_count_with_material_info, build_count_block, build_count_wood, build_count_frame, build_count_brick, build_count_monolith, build_count_panel, build_count_foam, build_count_slag, build_count_mix, raion_build_count_with_builddate_info, build_count_before_1920, build_count_1921-1945, build_count_1946-1970, build_count_1971-1995, build_count_after_1995, ID_metro, metro_min_avto, metro_km_avto, metro_min_walk, metro_km_walk, kindergarten_km, school_km, park_km, green_zone_km, industrial_km, water_treatment_km, cemetery_km, incineration_km, railroad_station_walk_km, railroad_station_walk_min, ID_railroad_station_walk, ...]
# Index: []
#
# [0 rows x 292 columns]

# %% [markdown]
# ## Notes
#
# Noise - check when life_sq is greater than full_sq
#
# Noise - 9 with 0 stories
#
# Reasoning for 1 story not being most common property.
#
# We saw that in the attribute floor, 1 floor was not the most common which we thought would be the case, instead 19 fllors was. Our rasoning behind why this ould be is because the dataset is just from a bank who are dealing ith transactions - and people would buy and sell apartments more often than rural 1 story houses. Moreover, there would be more apartments being bought and sold nowadays due to them being constructed more often.
